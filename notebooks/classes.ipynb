# %%
# %pip install datasets matplotlib huggingface_hub
# Out:
# Collecting datasets
#   Using cached datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib in /home/agrosavia/anaconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: huggingface_hub in /home/agrosavia/anaconda3/lib/python3.12/site-packages (0.25.1)
# Requirement already satisfied: filelock in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: packaging in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: pytz>=2020.1 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/agrosavia/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2023.3)
# Using cached datasets-3.2.0-py3-none-any.whl (480 kB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Installing collected packages: xxhash, multiprocess, datasets
# Successfully installed datasets-3.2.0 multiprocess-0.70.16 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import login

login("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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/agrosavia/.cache/huggingface/token
# Login successful

# %%
from datasets import load_dataset

dataset_name = "SemilleroCV/Cocoa-dataset"
dataset = load_dataset(dataset_name)

# Display the dataset structure
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 1843
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 463
#     })
# })

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count the occurrences of each class in the training set
label_counts = Counter(dataset["train"]["label"])

# Convert label IDs to their string names (if applicable)
label_names = dataset["train"].features["label"].names
label_counts_named = {label_names[label]: count for label, count in label_counts.items()}

# Plot the distribution
plt.figure(figsize=(10, 6))
plt.bar(label_counts_named.keys(), label_counts_named.values(), color='skyblue')
plt.xlabel("Class Labels")
plt.ylabel("Number of Samples")
plt.title("Class Distribution in SemilleroCV/Cocoa-dataset")
plt.xticks(rotation=45)
plt.show()
